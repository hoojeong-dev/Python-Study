# %% [markdown]
# # 네이버 뉴스 수집(from NAVER OpenAPI)
# - [API 목록](https://developers.naver.com/products/intro/plan/)

# %% [markdown]
# ## 검색 API 신청
# - [검색](https://developers.naver.com/products/search/)
# # - [오픈API이용신청](https://developers.naver.com/apps/#/register?defaultScope=search) (naver login 필요)

# %% [markdown]
# ### 애플리케이션 등록
# - 애플리케이션 이름
#   - sunmoon-search-학번
# - 사용 API
#   - 검색
# - 비로그인 오픈 API 서비스 환경(필수값)
#   - WEB 설정(임의의 주소)
#     - http://search-학번.sunmoon.ac.kr

# %% [markdown]
# ### api 사용 가이드
# - [비로그인 방식 오픈 API](https://developers.naver.com/docs/common/openapiguide/apilist.md#%EB%B9%84%EB%A1%9C%EA%B7%B8%EC%9D%B8-%EB%B0%A9%EC%8B%9D-%EC%98%A4%ED%94%88-api)
# - [검색 API](https://developers.naver.com/docs/common/openapiguide/apilist.md#%EA%B2%80%EC%83%89)
# - [뉴스 검색 API SPEC](https://developers.naver.com/docs/search/news/)
# - [검색 API 예제](https://developers.naver.com/docs/search/blog/)

# %% [markdown]
# ## 뉴스검색 with Python
# - 준비물
#   - [내 애플리케이션](https://developers.naver.com/apps/#/list) 의
#     - client_id
#     - client_secret
#
# ```
# # 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# # 네이버 검색 Open API 예제 - 블로그 검색
# import os
# import sys
# import urllib.request
# client_id = "YOUR_CLIENT_ID"
# client_secret = "YOUR_CLIENT_SECRET"
# encText = urllib.parse.quote("검색할 단어")
# url = "https://openapi.naver.com/v1/search/news.json?query=" + encText # json 결과
# # url = "https://openapi.naver.com/v1/search/news.xml?query=" + encText # xml 결과
# request = urllib.request.Request(url)
# request.add_header("X-Naver-Client-Id",client_id)
# request.add_header("X-Naver-Client-Secret",client_secret)
# response = urllib.request.urlopen(request)
# rescode = response.getcode()
# if(rescode==200):
#     response_body = response.read()
#     print(response_body.decode('utf-8'))
# else:
#     print("Error Code:" + rescode)
# ```

# %%
client_id = "LjnngQjFn1291UOAe_IN"
client_secret = "2nNqMGJWlZ"

# %% [markdown]
# ### 뉴스검색 실행
# - 키워드 : 아이폰

# %%
import os
import sys
import urllib.request
encText = urllib.parse.quote("아이폰")
url = "https://openapi.naver.com/v1/search/news.json?query=" + encText  # json 결과
# url = "https://openapi.naver.com/v1/search/news.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
  response_body = response.read()
  print(response_body.decode('utf-8'))
else:
  print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Sat, 09 Jan 2021 14:29:42 +0900",
# "total": 577664,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "맘스폰, 갤럭시S21 출시 전 'S20 울트라·Z 플립 5G·S20 FE' 할인 진행",
# "originallink": "http://www.beyondpost.co.kr/view.php?ud=2021010909024661176cf2d78c68_30",
# "link": "http://www.beyondpost.co.kr/view.php?ud=2021010909024661176cf2d78c68_30",
# "description": "및 <b>아이폰</b>12 시리즈 견제를 위한 전략으로 파악된다. 이러한 가운데 스마트폰 공구 할인카페 ‘맘스폰’... 갤럭시A31, <b>아이폰</b>SE2, <b>아이폰</b>7 등을 추가 결제금 없는 현금가 0원으로 판매한다. ‘맘스폰’관계자는... ",
# "pubDate": "Sat, 09 Jan 2021 14:03:00 +0900"
#
# },
# {
# "title": "중국 ‘에어팟 프로’엔 소가 있다…애플도 뛰어든 ‘소띠 에디션’ 특수",
# "originallink": "https://biz.chosun.com/site/data/html_dir/2021/01/09/2021010900465.html?utm_source=naver&utm_medium=original&utm_campaign=biz",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=104&oid=366&aid=0000649336",
# ...

# %% [markdown]
# ### 뉴스검색 옵션 변경

# %%
import os
import sys
import urllib.request
encText = urllib.parse.quote("아이폰")
url = "https://openapi.naver.com/v1/search/news.json?query=" + encText  + "&display=100" # json 결과
# url = "https://openapi.naver.com/v1/search/news.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
  response_body = response.read()
  print(response_body.decode('utf-8'))
else:
  print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Sat, 09 Jan 2021 14:29:44 +0900",
# "total": 577664,
# "start": 1,
# "display": 100,
# "items": [
# {
# "title": "맘스폰, 갤럭시S21 출시 전 'S20 울트라·Z 플립 5G·S20 FE' 할인 진행",
# "originallink": "http://www.beyondpost.co.kr/view.php?ud=2021010909024661176cf2d78c68_30",
# "link": "http://www.beyondpost.co.kr/view.php?ud=2021010909024661176cf2d78c68_30",
# "description": "및 <b>아이폰</b>12 시리즈 견제를 위한 전략으로 파악된다. 이러한 가운데 스마트폰 공구 할인카페 ‘맘스폰’... 갤럭시A31, <b>아이폰</b>SE2, <b>아이폰</b>7 등을 추가 결제금 없는 현금가 0원으로 판매한다. ‘맘스폰’관계자는... ",
# "pubDate": "Sat, 09 Jan 2021 14:03:00 +0900"
#
# },
# {
# "title": "중국 ‘에어팟 프로’엔 소가 있다…애플도 뛰어든 ‘소띠 에디션’ 특수",
# "originallink": "https://biz.chosun.com/site/data/html_dir/2021/01/09/2021010900465.html?utm_source=naver&utm_medium=original&utm_campaign=biz",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=104&oid=366&aid=0000649336",
# ...

# %% [markdown]
# ## pandas를 이용하여 읽기

# %%
import pandas as pd
import json

# %%
data = json.loads(response_body.decode('utf-8'))

# %%
df = pd.json_normalize(data['items'])

# %%
df
# Out:
#                                                 title  ...                          pubDate
# 0     맘스폰, 갤럭시S21 출시 전 'S20 울트라·Z 플립 5G·S20 FE' 할인 진행  ...  Sat, 09 Jan 2021 14:03:00 +0900
# 1              중국 ‘에어팟 프로’엔 소가 있다…애플도 뛰어든 ‘소띠 에디션’ 특수  ...  Sat, 09 Jan 2021 12:26:00 +0900
# 2        역대급으로 싼 갤럭시S21 “30만원 더 싼 샤오미보다 못하다?” [IT선빵!]  ...  Sat, 09 Jan 2021 12:12:00 +0900
# 3                  실적 기록 연신 갈아치운 삼성·LG, '위기 속 선방' 빛났다  ...  Sat, 09 Jan 2021 10:12:00 +0900
# 4   [D:크레딧㉓] 로얄다이브 &quot;백현 '놀이공원'·태용 '롱 플라이트' 세상 ...  ...  Sat, 09 Jan 2021 10:04:00 +0900
# ..                                                ...  ...                              ...
# 95             애플, <b>아이폰</b> 및 아이패드용 전원 어댑터 작고 가벼워진다  ...  Fri, 08 Jan 2021 15:23:00 +0900
# 96                 “삼성전기, 업황 개선에도 경쟁사대비 여전히 저평가되어 있다”  ...  Fri, 08 Jan 2021 15:19:00 +0900
# 97             '위기를 기회로' LG전자, 작년 매출 63조 '역대 최대' [종합]  ...  Fri, 08 Jan 2021 15:18:00 +0900
# ...

# %% [markdown]
# ## paging을 이용하여 10,000 개의 뉴스 수집
# - query : 아이폰
# - display : 100
# - start : 1 ~ 100

# %%
def patch_news_by_page(query, display=10, start=1):
    import os
    import sys
    import urllib.request
    import json
    encText = urllib.parse.quote(query)
    url = "https://openapi.naver.com/v1/search/news.json?query=" + encText  + "&display=" + str(display) + "&start=" + str(start) # json 결과
    # url = "https://openapi.naver.com/v1/search/news.xml?query=" + encText # xml 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
      response_body = response.read()
      # print(response_body.decode('utf-8'))
      # return response_body.decode('utf-8')
      return json.loads(response_body.decode('utf-8'))
    else:
      print("Error Code:" + rescode)
      return "Error Code:" + rescode

# %%
# data = patch_news_by_page("아이폰", 100, 1)

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.append.html 
df = pd.DataFrame()

for page in range(1, 11): 
    data_page = patch_news_by_page("애플", 100, page)
    df_page = pd.json_normalize(data_page['items']) 
    df = df.append(df_page, ignore_index=True)

# %%
len(df)
# Out:
# 1000

# %%
df.head(5)
# Out:
#                                              title  ...                          pubDate
# 0                               전남도, 모범 부동산중개업소 선정  ...  Sat, 09 Jan 2021 14:09:00 +0900
# 1  3100도 뚫은 불타는 코스피에도 부산 상장사는 친환경차 부품사 외 큰 영향 없...  ...  Sat, 09 Jan 2021 13:58:00 +0900
# 2                            '단기 급등' 코스피, 숨고르기 할까?  ...  Sat, 09 Jan 2021 13:41:00 +0900
# 3                작년 4분기 삼성전자 환율에 ‘울고’ LG전자 車에 ‘웃고’  ...  Sat, 09 Jan 2021 13:27:00 +0900
# 4                       테슬라 시총 8300억 달러 돌파…페이스북 제쳐  ...  Sat, 09 Jan 2021 13:22:00 +0900
#
# [5 rows x 5 columns]

# %%
df[['title', 'description', 'pubDate']].head(5)
# Out:
#                                              title  ...                          pubDate
# 0                               전남도, 모범 부동산중개업소 선정  ...  Sat, 09 Jan 2021 14:09:00 +0900
# 1  3100도 뚫은 불타는 코스피에도 부산 상장사는 친환경차 부품사 외 큰 영향 없...  ...  Sat, 09 Jan 2021 13:58:00 +0900
# 2                            '단기 급등' 코스피, 숨고르기 할까?  ...  Sat, 09 Jan 2021 13:41:00 +0900
# 3                작년 4분기 삼성전자 환율에 ‘울고’ LG전자 車에 ‘웃고’  ...  Sat, 09 Jan 2021 13:27:00 +0900
# 4                       테슬라 시총 8300억 달러 돌파…페이스북 제쳐  ...  Sat, 09 Jan 2021 13:22:00 +0900
#
# [5 rows x 3 columns]

# %% [markdown]
# ### pandas dataframe to file
# ```
# df.to_csv
# df.to_excel
# df.to_json
# df.to_pickle
# df.to ...
# ```
# [api reference](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_pickle.html)

# %%
df.to_pickle('애플_news_20210109.pkl')

# %% [markdown]
# ## 컨텐츠 수집
# - 삼성(1,11)    : 10page * 100 = 1,000
# - 아이폰(1,101) : 100page * 100 = 10,000
# - 갤럭시(1,101)
# - 샤오미(1,101)

# %%
# df = pd.DataFrame()

# for page in range(1, 11): 
#     data_page = patch_news_by_page("삼성", 100, page)
#     df_page = pd.json_normalize(data_page['items']) 
#     df = df.append(df_page, ignore_index=True)
# df.to_pickle('삼성_news_20210109.pkl')

# %% [markdown]
# ### 함수 만들기

# %%
def get_contents(keyword, max_page):
    df = pd.DataFrame()

    for page in range(1, max_page+1): 
        data_page = patch_news_by_page(keyword, 100, page)
        df_page = pd.json_normalize(data_page['items']) 
        df = df.append(df_page, ignore_index=True)
    df.to_pickle(keyword + '_news_20210109.pkl')

# %%
get_contents("삼성", 10)

# %%
get_contents("아이폰", 100)

# %% [markdown]
# # 실습

# %% [markdown]
# - 애플_news_20210109.pkl (1,000 건)
# - 삼성_news_20210109.pkl (1,000 건)
# - 아이폰_news_20210109.pkl (10,000 건)
# - 갤럭시_news_20210109.pkl (10,000 건)
# - 샤오미_news_20210109.pkl (10,000 건)
#
# 데이터 생성하고 local pc에 다운로드

# %%
get_contents("갤럭시", 100)

# %%
get_contents("샤오미", 100)
